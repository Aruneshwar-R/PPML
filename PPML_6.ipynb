# %% [markdown]
# <a href="https://colab.research.google.com/github/Aruneshwar-R/PPML/blob/main/PPML_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
print("DataFrame.apply function:\n")
info = pd.DataFrame([[2,71]]*3, columns=['P', 'Q'])
print("\nOriginalDataFrame:\n",info)
print("nSquare root of DataFrame:\n",info.apply(np.sqrt))
print("nSum of each column:\n",info.apply(np.sum, axis=0))
print("nSum of each row:n", info.apply(np.sum, axis=1))
# Out:
# DataFrame.apply function:
#
#
# OriginalDataFrame:
#     P   Q
# 0  2  71
# 1  2  71
# 2  2  71
# nSquare root of DataFrame:
#            P        Q
# 0  1.414214  8.42615
# 1  1.414214  8.42615
# 2  1.414214  8.42615
# nSum of each column:
#  P      6
# Q    213
# dtype: int64
# nSum of each row:n 0    73
# 1    73
# 2    73
# dtype: int64
# nOriginal DataFrame:n    X  Y  Z
# 0  1  5  7
# 1  2  7  8
# 2  3  6  9
# nMinimum and Maximum of each column:n
#      X  Y  Z
# min  1  5  7
# max  3  7  9

# %%
info=pd.DataFrame([[1,5,7],[2,7,8], [3,6,9]],columns=['X','Y','Z'])
print("\nOriginal DataFrame:\n",info)
print("\nMinimum and Maximum of each column:\n")
print(info.agg(['min','max']))
# Out:
# Original DataFrame:
#     X  Y  Z
# 0  1  5  7
# 1  2  7  8
# 2  3  6  9
#
# Minimum and Maximum of each column:
#
#      X  Y  Z
# min  1  5  7
# max  3  7  9

# %%
print("\nDataFrame.Assign function:\n")
d2=pd.DataFrame([['dale',123],['mark',143]],columns=['Emp','ID'])
print("\nOriginal Data Frame:\n",d2)
d2['Age']=[35,40]
print("\nAdding New coloumn:\n",d2)
d=d2.assign(Sex=['Male','Male'])
print("\nAdding new coloumn:\n",d)
# Out:
# DataFrame.Assign function:
#
#
# Original Data Frame:
#      Emp   ID
# 0  dale  123
# 1  mark  143
#
# Adding New coloumn:
#      Emp   ID  Age
# 0  dale  123   35
# 1  mark  143   40
#
# Adding new coloumn:
#      Emp   ID  Age   Sex
# 0  dale  123   35  Male
# 1  mark  143   40  Male

# %%
#DataFrame.Sort function
print("\nDataFrame.Sort function:\n")
info=pd.DataFrame(np.random.randn(5,2), index=[3,2,0,4,1],columns= ['col3','col4'])
print(info)
info2=info.sort_index()
print("\nSort index:\n",info2)
#info - pd.DataFrame({'coll':[7,1,8,3],'col2':[8,12,4,9]})
info3=info.sort_values(by='col3')
print("\nSort Values:\n",info3)
# Out:
# DataFrame.Sort function:
#
#        col3      col4
# 3 -1.575559 -0.691154
# 2 -1.677305  0.554670
# 0 -1.541234 -0.104874
# 4  1.174203 -0.471400
# 1  1.580748 -0.227850
#
# Sort index:
#         col3      col4
# 0 -1.541234 -0.104874
# 1  1.580748 -0.227850
# 2 -1.677305  0.554670
# 3 -1.575559 -0.691154
# 4  1.174203 -0.471400
#
# Sort Values:
#         col3      col4
# 2 -1.677305  0.554670
# 3 -1.575559 -0.691154
# 0 -1.541234 -0.104874
# 4  1.174203 -0.471400
# 1  1.580748 -0.227850

# %%
print("\nDataFrame.Merge function:\n")
left = pd.DataFrame({ 'id': [1,2,3,4,5], 'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
'sub':['sub1','sub2', 'sub4', 'sub6', 'sub5']} )
right= pd.DataFrame({ 'id':[1,2,3,4,5], 'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
'sub':['sub2','sub4', 'sub3', 'sub6','sub5']})
print(left)
print(right)
print(pd.merge(left,right,on='id'))
# Out:
# DataFrame.Merge function:
#
#    id    Name   sub
# 0   1    Alex  sub1
# 1   2     Amy  sub2
# 2   3   Allen  sub4
# 3   4   Alice  sub6
# 4   5  Ayoung  sub5
#    id   Name   sub
# 0   1  Billy  sub2
# 1   2  Brian  sub4
# 2   3   Bran  sub3
# 3   4  Bryce  sub6
# 4   5  Betty  sub5
#    id  Name_x sub_x Name_y sub_y
# 0   1    Alex  sub1  Billy  sub2
# 1   2     Amy  sub2  Brian  sub4
# 2   3   Allen  sub4   Bran  sub3
# 3   4   Alice  sub6  Bryce  sub6
# 4   5  Ayoung  sub5  Betty  sub5
