# %% [markdown]
# <a href="https://colab.research.google.com/github/Aruneshwar-R/PPML/blob/main/PPML_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],
index=['one', 'two','three'],
columns=['a','b','c'])
print(df)
# Out:
#        a  b  c
# one    1  2  3
# two    4  5  6
# three  7  8  9

# %%
print("Taking the input from Dataframe and storing in the Excel file")
df.to_excel('pandas_to_excel.xlsx', sheet_name='new_sheet_name')
# Out:
# Taking the input from Dataframe and storing in the Excel file

# %%
#Second Dataframe input to another Excel file
d = pd.DataFrame([[110, 210, 310], [12, 220, 320], [310, 320, 330]], index=['four', 'five', 'six'], columns=['a', 'b', 'c'])
d.to_excel('pandas_to_excell.xlsx', sheet_name='new_sheet_name')
# Out:
#         a    b    c
# four  110  210  310
# five   12  220  320
# six   310  320  330

# %%
#Merging two Excel files input into third file
x=pd.read_excel('pandas_to_excel.xlsx')
y=pd.read_excel('pandas_to_excell.xlsx')
z=pd.concat([x,y])
z.to_excel('d:\pandas_to_excel3.xlsx')
print(z)
# Out:
#   Unnamed: 0    a    b    c
# 0        one    1    2    3
# 1        two    4    5    6
# 2      three    7    8    9
# 0       four  110  210  310
# 1       five   12  220  320
# 2        six  310  320  330
# <>:5: SyntaxWarning: invalid escape sequence '\p'
# <>:5: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_1539/3763677737.py:5: SyntaxWarning: invalid escape sequence '\p'
#   z.to_excel('d:\pandas_to_excel3.xlsx')

# %%
df-pd.read_excel('d:\pandas_to_excel3.xlsx')
print(df)
print(list(df))
print(format(len(df)))
# Out:
#        a  b  c
# one    1  2  3
# two    4  5  6
# three  7  8  9
# ['a', 'b', 'c']
# 3
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_1539/1683137006.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df-pd.read_excel('d:\pandas_to_excel3.xlsx')
